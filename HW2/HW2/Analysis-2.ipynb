# %% [markdown]
# # Analysis Questions For HW2
#
# ## Question 1
#
# When loading the data, it wasn't very hard. I just had to install the kagglehub module and import it to my ipynb file.
# Then, the website provided had a code snippet to insert into my file that downloaded the data via the pandas read_csv method.
# The only problems I ran into were downloading the module and getting it running on my machine.

# %% [markdown]
# ## Question 2
#
# To find the missing values, I just used the isna() method from pandas. Then, I got the sum of
# all those columns with the sum() method. This returned the sum of all na values in each column.
# In the notebook, I say what the returned data showed. After, I had to do all of the preprocessing and
# plotting, but after that was done, I was able to impute the data with the SimpleImputer from sklearn.
# I used various methods in the SimpleImputer. For one pipeline, I used the median strategy. This is
# because it was the numerical data that I was imputing on. For the categorical data, I used the constant
# strategy because and median imputating doesn't do anything on categorical data.
#
# ## Question 3
#
# When it comes to streamlining the preprocessing, these methods basically just allows us to
# numerically or categorically impute, scale, and encode the date all in one step. Intrinsically, this
# takes away certain opertunities where we may have made a mistake by say calling the fit function too
# early. This could cause data leakage and other misc. mistakes that may be made when manually doing all
# of the afirmentioned tasks.
#
# ## Question 4
#
# The features that have a strong relationship with attack_detected are the failed_logins, login_attemps and
# ip_reputation_score. These three have the highest 3 relationships to attack_detected. This basically
# just tells us that they have strong correlations to attack attempts. For example, a failed login attempt tends
# to be related to attacks attempts more often than other features. That doesn't mean the failed logins are
# actually signs of attack attempts. It just means the diagnosed attack attempts were seen as related to
# a failed login attempt more than any other feature.
